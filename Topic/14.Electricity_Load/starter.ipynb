# %% [markdown]
# # Topic 14 – Electricity Load Diagrams (Energy Consumption, Library Dataset)
#
# **Level:** Hard
# **Goal:** Model and forecast electricity demand (multiple time series, rich seasonality).
#
# ## Dataset
# - **Source:** Electricity load diagrams dataset
# - **Link:** https://huggingface.co/datasets/tulipa762/electricity_load_diagrams
#
# ## Download Instructions
# 1. Open the link above
# 2. Download the CSV file containing the load data (if provided)
# 3. Save to `data/electricity/`

# %% [markdown]
# ## Installation
#
# Install required packages:

# %%
# !pip install pandas numpy matplotlib seaborn statsmodels scikit-learn

# %% [markdown]
# ## Data Loading
#
# Load the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# %%
df = pd.read_csv("data/electricity/electricity.csv")  # adjust filenamedf["timestamp"] = pd.to_datetime(df["timestamp"])df = df.set_index("timestamp").sort_index()

# %%
# Check for missing values
print("Missing values:")
print(df.isnull().sum())

# Basic statistics
print(f"\nBasic statistics:")
df.describe()

# %%
# Plot the time series
plt.figure(figsize=(12, 6))
plt.plot(df.index, df.iloc[:, 0], linewidth=1.5)
plt.title("Time Series Plot", fontsize=14, fontweight='bold')
plt.xlabel("Date", fontsize=12)
plt.ylabel("Value", fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
